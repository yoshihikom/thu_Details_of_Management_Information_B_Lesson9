# %%
import requests
import pandas as pd

# APIのエンドポイント
url = 'https://disclosure.edinet-fsa.go.jp/api/v2/documents.json'

# パラメータの設定（例: 2025年5月19日の書類を取得）
params = {
    'date': '2025-05-19',
    'type': 2,  # 2は有価証券報告書などの決算書類
    "Subscription-Key":"発行したAPI鍵"
}

# APIリクエストを送信
response = requests.get(url, params=params)

# レスポンスのJSONデータを取得
data = response.json()
data
# Out:
# {'metadata': {'title': '提出された書類を把握するためのAPI',
#   'parameter': {'date': '2025-05-19', 'type': '2'},
#   'resultset': {'count': 170},
#   'processDateTime': '2025-05-26 00:00',
#   'status': '200',
#   'message': 'OK'},
#  'results': [{'seqNumber': 1,
#    'docID': 'S100VRUR',
#    'edinetCode': 'E03752',
#    'secCode': '86040',
#    'JCN': '7010001034881',
#    'filerName': '野村ホールディングス株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '113001',
#    'docTypeCode': '090',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:00',
#    'docDescription': '訂正発行登録書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100U67D',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '0',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '0',
#    'legalStatus': '1'},
#   {'seqNumber': 2,
#    'docID': 'S100VOIS',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G11591',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-08-27',
#    'periodEnd': '2025-02-26',
#    'submitDateTime': '2025-05-19 09:01',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第18期(2024/08/27－2025/02/26)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 3,
#    'docID': 'S100VDYF',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G01146',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-19',
#    'submitDateTime': '2025-05-19 09:01',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第26期(2024/08/20－2025/08/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 4,
#    'docID': 'S100VRDA',
#    'edinetCode': 'E40609',
#    'secCode': None,
#    'JCN': '1010001193931',
#    'filerName': '結キャピタル・パートナーズ株式会社',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010002',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:01',
#    'docDescription': '変更報告書',
#    'issuerEdinetCode': 'E39668',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 5,
#    'docID': 'S100VPYS',
#    'edinetCode': 'E12460',
#    'secCode': None,
#    'JCN': '7010001054021',
#    'filerName': '野村アセットマネジメント株式会社',
#    'fundCode': 'G05171',
#    'ordinanceCode': '030',
#    'formCode': '995000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:01',
#    'docDescription': '臨時報告書（内国特定有価証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第29条第2項第4号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 6,
#    'docID': 'S100VDYC',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G01146',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:02',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 7,
#    'docID': 'S100VJO9',
#    'edinetCode': 'E12444',
#    'secCode': None,
#    'JCN': '8010001114914',
#    'filerName': '三井住友トラスト・アセットマネジメント株式会社',
#    'fundCode': 'G07363',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-18',
#    'submitDateTime': '2025-05-19 09:02',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第17期(2024/08/20－2025/08/18)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 8,
#    'docID': 'S100VMTO',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G12651',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-21',
#    'periodEnd': '2025-08-20',
#    'submitDateTime': '2025-05-19 09:02',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第8期(2024/08/21－2025/08/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 9,
#    'docID': 'S100VOIV',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G11591',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:02',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 10,
#    'docID': 'S100VQ5Z',
#    'edinetCode': 'E10677',
#    'secCode': None,
#    'JCN': '9010001021473',
#    'filerName': 'アセットマネジメントＯｎｅ株式会社',
#    'fundCode': 'G11803',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-19',
#    'submitDateTime': '2025-05-19 09:02',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第64期(2024/08/20－2025/08/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 11,
#    'docID': 'S100VDYH',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G02538',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-20',
#    'periodEnd': '2025-02-19',
#    'submitDateTime': '2025-05-19 09:02',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第64期(2024/02/20－2025/02/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 12,
#    'docID': 'S100VQLQ',
#    'edinetCode': 'E12448',
#    'secCode': None,
#    'JCN': '8010401040306',
#    'filerName': '明治安田アセットマネジメント株式会社',
#    'fundCode': 'G02750',
#    'ordinanceCode': '030',
#    'formCode': '995000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:03',
#    'docDescription': '臨時報告書（内国特定有価証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第29条第2項第4号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 13,
#    'docID': 'S100VMTP',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G12651',
#    'ordinanceCode': '030',
#    'formCode': '04A001',
#    'docTypeCode': '040',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:03',
#    'docDescription': '訂正有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100UJIS',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 14,
#    'docID': 'S100VDYJ',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G02847',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-19',
#    'submitDateTime': '2025-05-19 09:03',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第64期(2024/08/20－2025/08/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 15,
#    'docID': 'S100VOK9',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G11592',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-08-27',
#    'periodEnd': '2025-02-26',
#    'submitDateTime': '2025-05-19 09:03',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第18期(2024/08/27－2025/02/26)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 16,
#    'docID': 'S100VDYM',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G03074',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-19',
#    'submitDateTime': '2025-05-19 09:04',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第24期(2024/08/20－2025/08/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 17,
#    'docID': 'S100VMTQ',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G03212',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-21',
#    'periodEnd': '2025-02-20',
#    'submitDateTime': '2025-05-19 09:04',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第24期(2024/02/21－2025/02/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 18,
#    'docID': 'S100VOT7',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G05049',
#    'ordinanceCode': '030',
#    'formCode': '04A001',
#    'docTypeCode': '040',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:04',
#    'docDescription': '訂正有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100UJJR',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 19,
#    'docID': 'S100VQ62',
#    'edinetCode': 'E10677',
#    'secCode': None,
#    'JCN': '9010001021473',
#    'filerName': 'アセットマネジメントＯｎｅ株式会社',
#    'fundCode': 'G11963',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-19',
#    'submitDateTime': '2025-05-19 09:04',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第54期(2024/08/20－2025/08/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 20,
#    'docID': 'S100VDYL',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G03074',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:05',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 21,
#    'docID': 'S100VJO8',
#    'edinetCode': 'E12444',
#    'secCode': None,
#    'JCN': '8010001114914',
#    'filerName': '三井住友トラスト・アセットマネジメント株式会社',
#    'fundCode': 'G07363',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:05',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 22,
#    'docID': 'S100VQ60',
#    'edinetCode': 'E10677',
#    'secCode': None,
#    'JCN': '9010001021473',
#    'filerName': 'アセットマネジメントＯｎｅ株式会社',
#    'fundCode': 'G11957',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-20',
#    'periodEnd': '2025-02-19',
#    'submitDateTime': '2025-05-19 09:05',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第54期(2024/02/20－2025/02/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 23,
#    'docID': 'S100VMA8',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G05049',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-21',
#    'periodEnd': '2025-08-20',
#    'submitDateTime': '2025-05-19 09:05',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第19期(2024/08/21－2025/08/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 24,
#    'docID': 'S100VMTR',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G03212',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:05',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 25,
#    'docID': 'S100VDYQ',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G14241',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-18',
#    'submitDateTime': '2025-05-19 09:05',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第4期(2024/08/20－2025/08/18)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 26,
#    'docID': 'S100VLRC',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G08957',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:06',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 27,
#    'docID': 'S100VQ5X',
#    'edinetCode': 'E10677',
#    'secCode': None,
#    'JCN': '9010001021473',
#    'filerName': 'アセットマネジメントＯｎｅ株式会社',
#    'fundCode': 'G11797',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-20',
#    'periodEnd': '2025-02-19',
#    'submitDateTime': '2025-05-19 09:06',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第63期(2024/02/20－2025/02/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 28,
#    'docID': 'S100VQ0G',
#    'edinetCode': 'E12444',
#    'secCode': None,
#    'JCN': '8010001114914',
#    'filerName': '三井住友トラスト・アセットマネジメント株式会社',
#    'fundCode': 'G07364',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-18',
#    'submitDateTime': '2025-05-19 09:06',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第17期(2024/08/20－2025/08/18)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 29,
#    'docID': 'S100VOKA',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G11592',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:06',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 30,
#    'docID': 'S100VDYO',
#    'edinetCode': 'E12430',
#    'secCode': None,
#    'JCN': '8010401072159',
#    'filerName': '日興アセットマネジメント株式会社',
#    'fundCode': 'G14241',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:06',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 31,
#    'docID': 'S100VLRD',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G08957',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-21',
#    'periodEnd': '2025-02-20',
#    'submitDateTime': '2025-05-19 09:07',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第13期(2024/02/21－2025/02/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 32,
#    'docID': 'S100VOI3',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G14424',
#    'ordinanceCode': '030',
#    'formCode': '04A001',
#    'docTypeCode': '040',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:07',
#    'docDescription': '訂正有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100TH5O',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 33,
#    'docID': 'S100VQB5',
#    'edinetCode': 'E32011',
#    'secCode': None,
#    'JCN': '5010601048309',
#    'filerName': 'りそなアセットマネジメント株式会社',
#    'fundCode': 'G15532',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:08',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 34,
#    'docID': 'S100VRPT',
#    'edinetCode': 'E03268',
#    'secCode': '75120',
#    'JCN': '4430001015958',
#    'filerName': 'イオン北海道株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '030001',
#    'docTypeCode': '130',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:10',
#    'docDescription': '訂正有価証券報告書－第43期(2020/03/01－2021/02/28)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100LCPV',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 35,
#    'docID': 'S100VP2G',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G13531',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-08-27',
#    'periodEnd': '2025-02-26',
#    'submitDateTime': '2025-05-19 09:10',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第11期(2024/08/27－2025/02/26)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 36,
#    'docID': 'S100VMSU',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G01321',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-21',
#    'periodEnd': '2025-02-20',
#    'submitDateTime': '2025-05-19 09:11',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第25期(2024/02/21－2025/02/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 37,
#    'docID': 'S100VL3L',
#    'edinetCode': 'E12492',
#    'secCode': None,
#    'JCN': '3010001124868',
#    'filerName': 'ＨＳＢＣアセットマネジメント株式会社',
#    'fundCode': 'G11299',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-19',
#    'submitDateTime': '2025-05-19 09:11',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第10期(2024/08/20－2025/08/19)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 38,
#    'docID': 'S100VQSO',
#    'edinetCode': 'E03439',
#    'secCode': '33330',
#    'JCN': '7120001006861',
#    'filerName': '株式会社あさひ',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '030000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-21',
#    'periodEnd': '2025-02-20',
#    'submitDateTime': '2025-05-19 09:11',
#    'docDescription': '有価証券報告書－第50期(2024/02/21－2025/02/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 39,
#    'docID': 'S100VP2H',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G13531',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:12',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 40,
#    'docID': 'S100VMSV',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G01321',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:12',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 41,
#    'docID': 'S100VR10',
#    'edinetCode': 'E12492',
#    'secCode': None,
#    'JCN': '3010001124868',
#    'filerName': 'ＨＳＢＣアセットマネジメント株式会社',
#    'fundCode': 'G05365',
#    'ordinanceCode': '030',
#    'formCode': '995000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:12',
#    'docDescription': '臨時報告書（内国特定有価証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第29条第2項第4号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 42,
#    'docID': 'S100VRX9',
#    'edinetCode': 'E03268',
#    'secCode': '75120',
#    'JCN': '4430001015958',
#    'filerName': 'イオン北海道株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '042100',
#    'docTypeCode': '135',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:13',
#    'docDescription': '確認書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VRPT',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '0',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '0',
#    'legalStatus': '1'},
#   {'seqNumber': 43,
#    'docID': 'S100VQ0F',
#    'edinetCode': 'E12444',
#    'secCode': None,
#    'JCN': '8010001114914',
#    'filerName': '三井住友トラスト・アセットマネジメント株式会社',
#    'fundCode': 'G07364',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:13',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 44,
#    'docID': 'S100VOZ8',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G14423',
#    'ordinanceCode': '030',
#    'formCode': '04A001',
#    'docTypeCode': '040',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:14',
#    'docDescription': '訂正有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100TDI4',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 45,
#    'docID': 'S100VRRU',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G06779',
#    'ordinanceCode': '030',
#    'formCode': '07A001',
#    'docTypeCode': '130',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:14',
#    'docDescription': '訂正有価証券報告書（内国投資信託受益証券）－第34期(2024/07/17－2025/01/15)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VG61',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 46,
#    'docID': 'S100VMSW',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G13133',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-02-21',
#    'periodEnd': '2025-02-20',
#    'submitDateTime': '2025-05-19 09:14',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第7期(2024/02/21－2025/02/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 47,
#    'docID': 'S100VRUV',
#    'edinetCode': 'E03268',
#    'secCode': '75120',
#    'JCN': '4430001015958',
#    'filerName': 'イオン北海道株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '030001',
#    'docTypeCode': '130',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:15',
#    'docDescription': '訂正有価証券報告書－第44期(2021/03/01－2022/02/28)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100O3FW',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 48,
#    'docID': 'S100VMSX',
#    'edinetCode': 'E11518',
#    'secCode': None,
#    'JCN': '9010001034450',
#    'filerName': '三菱ＵＦＪアセットマネジメント株式会社',
#    'fundCode': 'G13133',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:15',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 49,
#    'docID': 'S100VQSH',
#    'edinetCode': 'E03439',
#    'secCode': '33330',
#    'JCN': '7120001006861',
#    'filerName': '株式会社あさひ',
#    'fundCode': None,
#    'ordinanceCode': '015',
#    'formCode': '010000',
#    'docTypeCode': '235',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:15',
#    'docDescription': '内部統制報告書－第50期(2024/02/21－2025/02/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 50,
#    'docID': 'S100VRRV',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G06779',
#    'ordinanceCode': '030',
#    'formCode': '04A001',
#    'docTypeCode': '040',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:16',
#    'docDescription': '訂正有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VG65',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 51,
#    'docID': 'S100VQS9',
#    'edinetCode': 'E03439',
#    'secCode': '33330',
#    'JCN': '7120001006861',
#    'filerName': '株式会社あさひ',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '042000',
#    'docTypeCode': '135',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:16',
#    'docDescription': '確認書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '0',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '0',
#    'legalStatus': '1'},
#   {'seqNumber': 52,
#    'docID': 'S100VQBN',
#    'edinetCode': 'E12437',
#    'secCode': None,
#    'JCN': '8010001011855',
#    'filerName': 'パインブリッジ・インベストメンツ株式会社',
#    'fundCode': 'G03912',
#    'ordinanceCode': '030',
#    'formCode': '04A000',
#    'docTypeCode': '030',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:18',
#    'docDescription': '有価証券届出書（内国投資信託受益証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 53,
#    'docID': 'S100VQMN',
#    'edinetCode': 'E12481',
#    'secCode': None,
#    'JCN': '1010401025734',
#    'filerName': 'フィデリティ投信株式会社',
#    'fundCode': 'G04801',
#    'ordinanceCode': '030',
#    'formCode': '995000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:18',
#    'docDescription': '臨時報告書（内国特定有価証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第29条第2項第4号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 54,
#    'docID': 'S100VRXA',
#    'edinetCode': 'E03268',
#    'secCode': '75120',
#    'JCN': '4430001015958',
#    'filerName': 'イオン北海道株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '042100',
#    'docTypeCode': '135',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:18',
#    'docDescription': '確認書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VRUV',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '0',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '0',
#    'legalStatus': '1'},
#   {'seqNumber': 55,
#    'docID': 'S100VRRW',
#    'edinetCode': 'E06748',
#    'secCode': None,
#    'JCN': '2010001049257',
#    'filerName': '大和アセットマネジメント株式会社',
#    'fundCode': 'G07818',
#    'ordinanceCode': '030',
#    'formCode': '07A001',
#    'docTypeCode': '130',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:19',
#    'docDescription': '訂正有価証券報告書（内国投資信託受益証券）－第30期(2024/07/17－2025/01/15)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VHIJ',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 56,
#    'docID': 'S100VQMV',
#    'edinetCode': 'E12481',
#    'secCode': None,
#    'JCN': '1010401025734',
#    'filerName': 'フィデリティ投信株式会社',
#    'fundCode': 'G04815',
#    'ordinanceCode': '030',
#    'formCode': '995000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:19',
#    'docDescription': '臨時報告書（内国特定有価証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第29条第2項第4号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 57,
#    'docID': 'S100VRUX',
#    'edinetCode': 'E03268',
#    'secCode': '75120',
#    'JCN': '4430001015958',
#    'filerName': 'イオン北海道株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '030001',
#    'docTypeCode': '130',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:20',
#    'docDescription': '訂正有価証券報告書－第45期(2022/03/01－2023/02/28)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100QT6F',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 58,
#    'docID': 'S100VN6T',
#    'edinetCode': 'E12444',
#    'secCode': None,
#    'JCN': '8010001114914',
#    'filerName': '三井住友トラスト・アセットマネジメント株式会社',
#    'fundCode': 'G07362',
#    'ordinanceCode': '030',
#    'formCode': '10A000',
#    'docTypeCode': '160',
#    'periodStart': '2024-08-20',
#    'periodEnd': '2025-08-18',
#    'submitDateTime': '2025-05-19 09:21',
#    'docDescription': '半期報告書（内国投資信託受益証券）－第17期(2024/08/20－2025/08/18)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 59,
#    'docID': 'S100VQMS',
#    'edinetCode': 'E11161',
#    'secCode': None,
#    'JCN': '5010701017007',
#    'filerName': 'スパークス・アセット・マネジメント株式会社',
#    'fundCode': 'G05613',
#    'ordinanceCode': '030',
#    'formCode': '995000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 09:21',
#    'docDescription': '臨時報告書（内国特定有価証券）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第29条第2項第4号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 60,
#    'docID': 'S100VQBJ',
#    'edinetCode': 'E12437',
#    'secCode': None,
#    'JCN': '8010001011855',
#    'filerName': 'パインブリッジ・インベストメンツ株式会社',
#    'fundCode': 'G03912',
#    'ordinanceCode': '030',
#    'formCode': '07A000',
#    'docTypeCode': '120',
#    'periodStart': '2024-08-21',
#    'periodEnd': '2025-02-20',
#    'submitDateTime': '2025-05-19 09:22',
#    'docDescription': '有価証券報告書（内国投資信託受益証券）－第42期(2024/08/21－2025/02/20)',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
# ...
#    'ordinanceCode': '060',
#    'formCode': '090001',
#    'docTypeCode': '360',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:13',
#    'docDescription': '訂正報告書（大量保有報告書・変更報告書）',
#    'issuerEdinetCode': 'E38567',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VQ7M',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 151,
#    'docID': 'S100VS14',
#    'edinetCode': 'E38700',
#    'secCode': None,
#    'JCN': None,
#    'filerName': '牧\u3000寛之',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010000',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:17',
#    'docDescription': '大量保有報告書',
#    'issuerEdinetCode': 'E30650',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 152,
#    'docID': 'S100VS2U',
#    'edinetCode': 'E34453',
#    'secCode': None,
#    'JCN': '9010003028211',
#    'filerName': '合同会社インバウンドインベストメント',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '090001',
#    'docTypeCode': '360',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:22',
#    'docDescription': '訂正報告書（大量保有報告書・変更報告書）',
#    'issuerEdinetCode': 'E05651',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VS2C',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 153,
#    'docID': 'S100VS32',
#    'edinetCode': 'E30466',
#    'secCode': '36860',
#    'JCN': '6010001084845',
#    'filerName': '株式会社ディー・エル・イー',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:22',
#    'docDescription': '臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第12号,第19条第2項第19号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 154,
#    'docID': 'S100VS30',
#    'edinetCode': 'E04768',
#    'secCode': '85840',
#    'JCN': '2440001001001',
#    'filerName': '株式会社ジャックス',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '023001',
#    'docTypeCode': '040',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:25',
#    'docDescription': '訂正有価証券届出書（参照方式）',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VEKE',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 155,
#    'docID': 'S100VQWQ',
#    'edinetCode': 'E01593',
#    'secCode': '72590',
#    'JCN': '6180301013611',
#    'filerName': '株式会社アイシン',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:30',
#    'docDescription': '臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第2号の2',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 156,
#    'docID': 'S100VS0G',
#    'edinetCode': 'E33557',
#    'secCode': '65570',
#    'JCN': '6010601048836',
#    'filerName': 'ＡＩＡＩグループ株式会社',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010000',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:30',
#    'docDescription': '大量保有報告書',
#    'issuerEdinetCode': 'E34276',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 157,
#    'docID': 'S100VS2V',
#    'edinetCode': 'E01593',
#    'secCode': '72590',
#    'JCN': '6180301013611',
#    'filerName': '株式会社アイシン',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '113001',
#    'docTypeCode': '090',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:30',
#    'docDescription': '訂正発行登録書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100S35L',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '0',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '0',
#    'legalStatus': '1'},
#   {'seqNumber': 158,
#    'docID': 'S100VS1K',
#    'edinetCode': 'E05647',
#    'secCode': '43440',
#    'JCN': '3010401051654',
#    'filerName': 'ソースネクスト株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:30',
#    'docDescription': '臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第12号,第19条第2項第19号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 159,
#    'docID': 'S100VS35',
#    'edinetCode': 'E03245',
#    'secCode': '74500',
#    'JCN': '3420001005928',
#    'filerName': '株式会社サンデー',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:31',
#    'docDescription': '臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第9号の2',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 160,
#    'docID': 'S100VS3E',
#    'edinetCode': 'E34453',
#    'secCode': None,
#    'JCN': '9010003028211',
#    'filerName': '合同会社インバウンドインベストメント',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010002',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:33',
#    'docDescription': '変更報告書',
#    'issuerEdinetCode': 'E05651',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100TFVT',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 161,
#    'docID': 'S100VRSR',
#    'edinetCode': 'E33519',
#    'secCode': '39960',
#    'JCN': '1010001107305',
#    'filerName': 'サインポスト株式会社',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:34',
#    'docDescription': '臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第9号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 162,
#    'docID': 'S100VRWQ',
#    'edinetCode': 'E36069',
#    'secCode': None,
#    'JCN': None,
#    'filerName': 'Ｌｏｎｇ\u3000Ｃｏｒｒｉｄｏｒ\u3000Ａｓｓｅｔ\u3000Ｍａｎａｇｅｍｅｎｔ\u3000Ｌｉｍｉｔｅｄ',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010002',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:35',
#    'docDescription': '変更報告書',
#    'issuerEdinetCode': 'E27046',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 163,
#    'docID': 'S100VS34',
#    'edinetCode': 'E08939',
#    'secCode': None,
#    'JCN': None,
#    'filerName': 'スプラウスグローブインベストメントマネジメントリミテッド',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010002',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:39',
#    'docDescription': '変更報告書',
#    'issuerEdinetCode': 'E03418',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100ONMH',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 164,
#    'docID': 'S100VRTM',
#    'edinetCode': 'E33628',
#    'secCode': None,
#    'JCN': None,
#    'filerName': '武長\u3000太郎',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010002',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:48',
#    'docDescription': '変更報告書',
#    'issuerEdinetCode': 'E36757',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 165,
#    'docID': 'S100VRPO',
#    'edinetCode': 'E03061',
#    'secCode': '82670',
#    'JCN': '6040001003380',
#    'filerName': 'イオン株式会社',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '090001',
#    'docTypeCode': '360',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:53',
#    'docDescription': '訂正報告書（大量保有報告書・変更報告書）',
#    'issuerEdinetCode': 'E04874',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': 'S100VORN',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 166,
#    'docID': 'S100VRZE',
#    'edinetCode': 'E37744',
#    'secCode': '95540',
#    'JCN': '5012401024308',
#    'filerName': '株式会社ＡＶｉＣ',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:54',
#    'docDescription': '臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第3号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 167,
#    'docID': 'S100VRZF',
#    'edinetCode': 'E37744',
#    'secCode': '95540',
#    'JCN': '5012401024308',
#    'filerName': '株式会社ＡＶｉＣ',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053000',
#    'docTypeCode': '180',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 16:56',
#    'docDescription': '臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第3号',
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 168,
#    'docID': 'S100VQOU',
#    'edinetCode': 'E33097',
#    'secCode': None,
#    'JCN': None,
#    'filerName': '江口\u3000新',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010002',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 17:00',
#    'docDescription': '変更報告書',
#    'issuerEdinetCode': 'E32549',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 169,
#    'docID': 'S100VRQX',
#    'edinetCode': 'E40567',
#    'secCode': None,
#    'JCN': '8010001133096',
#    'filerName': '株式会社\u3000アイエスシー',
#    'fundCode': None,
#    'ordinanceCode': '060',
#    'formCode': '010002',
#    'docTypeCode': '350',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 17:03',
#    'docDescription': '変更報告書',
#    'issuerEdinetCode': 'E04246',
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': None,
#    'parentDocID': None,
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '1',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'},
#   {'seqNumber': 170,
#    'docID': 'S100VS3V',
#    'edinetCode': 'E39661',
#    'secCode': '186A0',
#    'JCN': '6010603007550',
#    'filerName': '株式会社アストロスケールホールディングス',
#    'fundCode': None,
#    'ordinanceCode': '010',
#    'formCode': '053001',
#    'docTypeCode': '190',
#    'periodStart': None,
#    'periodEnd': None,
#    'submitDateTime': '2025-05-19 17:08',
#    'docDescription': '訂正臨時報告書',
#    'issuerEdinetCode': None,
#    'subjectEdinetCode': None,
#    'subsidiaryEdinetCode': None,
#    'currentReportReason': '第19条第2項第1号',
#    'parentDocID': 'S100VPVY',
#    'opeDateTime': None,
#    'withdrawalStatus': '0',
#    'docInfoEditStatus': '0',
#    'disclosureStatus': '0',
#    'xbrlFlag': '1',
#    'pdfFlag': '1',
#    'attachDocFlag': '0',
#    'englishDocFlag': '0',
#    'csvFlag': '1',
#    'legalStatus': '1'}]}

# %%
# データフレームに変換
documents = data['results']
df = pd.DataFrame(documents)

# 特定のカラムだけを選択
df_filtered = df[['docID', 'secCode','edinetCode', 'filerName', 'docDescription', 'submitDateTime']]

# 決算情報のみをフィルタリング
df_financial = df_filtered[df_filtered['docDescription'].str.contains('有価証券報告書', na=False)]
df_financial
# Out:
#         docID secCode edinetCode                    filerName  \
# 1    S100VOIS    None     E06748             大和アセットマネジメント株式会社
# 10   S100VDYH    None     E12430             日興アセットマネジメント株式会社
# 14   S100VOK9    None     E06748             大和アセットマネジメント株式会社
# 16   S100VMTQ    None     E11518          三菱ＵＦＪアセットマネジメント株式会社
# 21   S100VQ60    None     E10677            アセットマネジメントＯｎｅ株式会社
# 26   S100VQ5X    None     E10677            アセットマネジメントＯｎｅ株式会社
# 30   S100VLRD    None     E11518          三菱ＵＦＪアセットマネジメント株式会社
# 33   S100VRPT   75120     E03268                   イオン北海道株式会社
# 34   S100VP2G    None     E06748             大和アセットマネジメント株式会社
# 35   S100VMSU    None     E11518          三菱ＵＦＪアセットマネジメント株式会社
# 37   S100VQSO   33330     E03439                      株式会社あさひ
# 44   S100VRRU    None     E06748             大和アセットマネジメント株式会社
# 45   S100VMSW    None     E11518          三菱ＵＦＪアセットマネジメント株式会社
# 46   S100VRUV   75120     E03268                   イオン北海道株式会社
# 54   S100VRRW    None     E06748             大和アセットマネジメント株式会社
# 56   S100VRUX   75120     E03268                   イオン北海道株式会社
# 59   S100VQBJ    None     E12437         パインブリッジ・インベストメンツ株式会社
# 62   S100VRV0   75120     E03268                   イオン北海道株式会社
# 66   S100VQBT    None     E12437         パインブリッジ・インベストメンツ株式会社
# 67   S100VRWR   82270     E03137                     株式会社しまむら
# 72   S100VRN9    None     E12457  ゴールドマン・サックス・アセット・マネジメント株式会社
# 73   S100VL4K    None     E12492           ＨＳＢＣアセットマネジメント株式会社
# 140  S100VRS0   97870     E04874                 イオンディライト株式会社
#
#                                         docDescription    submitDateTime
# 1      有価証券報告書（内国投資信託受益証券）－第18期(2024/08/27－2025/02/26)  2025-05-19 09:01
# 10     有価証券報告書（内国投資信託受益証券）－第64期(2024/02/20－2025/02/19)  2025-05-19 09:02
# 14     有価証券報告書（内国投資信託受益証券）－第18期(2024/08/27－2025/02/26)  2025-05-19 09:03
# 16     有価証券報告書（内国投資信託受益証券）－第24期(2024/02/21－2025/02/20)  2025-05-19 09:04
# 21     有価証券報告書（内国投資信託受益証券）－第54期(2024/02/20－2025/02/19)  2025-05-19 09:05
# 26     有価証券報告書（内国投資信託受益証券）－第63期(2024/02/20－2025/02/19)  2025-05-19 09:06
# 30     有価証券報告書（内国投資信託受益証券）－第13期(2024/02/21－2025/02/20)  2025-05-19 09:07
# 33               訂正有価証券報告書－第43期(2020/03/01－2021/02/28)  2025-05-19 09:10
# 34     有価証券報告書（内国投資信託受益証券）－第11期(2024/08/27－2025/02/26)  2025-05-19 09:10
# 35     有価証券報告書（内国投資信託受益証券）－第25期(2024/02/21－2025/02/20)  2025-05-19 09:11
# 37                 有価証券報告書－第50期(2024/02/21－2025/02/20)  2025-05-19 09:11
# 44   訂正有価証券報告書（内国投資信託受益証券）－第34期(2024/07/17－2025/01/15)  2025-05-19 09:14
# 45      有価証券報告書（内国投資信託受益証券）－第7期(2024/02/21－2025/02/20)  2025-05-19 09:14
# 46               訂正有価証券報告書－第44期(2021/03/01－2022/02/28)  2025-05-19 09:15
# 54   訂正有価証券報告書（内国投資信託受益証券）－第30期(2024/07/17－2025/01/15)  2025-05-19 09:19
# 56               訂正有価証券報告書－第45期(2022/03/01－2023/02/28)  2025-05-19 09:20
# 59     有価証券報告書（内国投資信託受益証券）－第42期(2024/08/21－2025/02/20)  2025-05-19 09:22
# 62               訂正有価証券報告書－第46期(2023/03/01－2024/02/29)  2025-05-19 09:25
# 66     有価証券報告書（内国投資信託受益証券）－第41期(2024/08/21－2025/02/20)  2025-05-19 09:32
# 67                 有価証券報告書－第72期(2024/02/21－2025/02/20)  2025-05-19 09:32
# 72     有価証券報告書（内国投資信託受益証券）－第20期(2024/08/20－2025/02/19)  2025-05-19 09:41
# 73     有価証券報告書（内国投資信託受益証券）－第14期(2024/08/20－2025/02/19)  2025-05-19 09:45
# 140                有価証券報告書－第52期(2024/03/01－2025/02/28)  2025-05-19 16:02

# %%
import urllib.request
import sys

# APIキーの設定
api_key = '発行したAPI鍵'

# ドキュメントのダウンロード
for index, doc in df_financial.iterrows():
    docID = doc['docID']
    url = f'https://api.edinet-fsa.go.jp/api/v2/documents/{docID}?type=5&Subscription-Key={api_key}'

    print(doc['edinetCode'], doc['docID'], doc['filerName'], doc['docDescription'], doc['submitDateTime'], sep='\t')

    try:
        # ZIPファイルのダウンロード
        with urllib.request.urlopen(url) as res:
            content = res.read()
        output_path = f'{docID}.zip'
        with open(output_path, 'wb') as file_out:
            file_out.write(content)
    except urllib.error.HTTPError as e:
        if e.code >= 400:
            sys.stderr.write(e.reason + '\n')
        else:
            raise e
# Out:
# E06748	S100VOIS	大和アセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第18期(2024/08/27－2025/02/26)	2025-05-19 09:01
# E12430	S100VDYH	日興アセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第64期(2024/02/20－2025/02/19)	2025-05-19 09:02
# E06748	S100VOK9	大和アセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第18期(2024/08/27－2025/02/26)	2025-05-19 09:03
# E11518	S100VMTQ	三菱ＵＦＪアセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第24期(2024/02/21－2025/02/20)	2025-05-19 09:04
# E10677	S100VQ60	アセットマネジメントＯｎｅ株式会社	有価証券報告書（内国投資信託受益証券）－第54期(2024/02/20－2025/02/19)	2025-05-19 09:05
# E10677	S100VQ5X	アセットマネジメントＯｎｅ株式会社	有価証券報告書（内国投資信託受益証券）－第63期(2024/02/20－2025/02/19)	2025-05-19 09:06
# E11518	S100VLRD	三菱ＵＦＪアセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第13期(2024/02/21－2025/02/20)	2025-05-19 09:07
# E03268	S100VRPT	イオン北海道株式会社	訂正有価証券報告書－第43期(2020/03/01－2021/02/28)	2025-05-19 09:10
# E06748	S100VP2G	大和アセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第11期(2024/08/27－2025/02/26)	2025-05-19 09:10
# E11518	S100VMSU	三菱ＵＦＪアセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第25期(2024/02/21－2025/02/20)	2025-05-19 09:11
# E03439	S100VQSO	株式会社あさひ	有価証券報告書－第50期(2024/02/21－2025/02/20)	2025-05-19 09:11
# E06748	S100VRRU	大和アセットマネジメント株式会社	訂正有価証券報告書（内国投資信託受益証券）－第34期(2024/07/17－2025/01/15)	2025-05-19 09:14
# E11518	S100VMSW	三菱ＵＦＪアセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第7期(2024/02/21－2025/02/20)	2025-05-19 09:14
# E03268	S100VRUV	イオン北海道株式会社	訂正有価証券報告書－第44期(2021/03/01－2022/02/28)	2025-05-19 09:15
# E06748	S100VRRW	大和アセットマネジメント株式会社	訂正有価証券報告書（内国投資信託受益証券）－第30期(2024/07/17－2025/01/15)	2025-05-19 09:19
# E03268	S100VRUX	イオン北海道株式会社	訂正有価証券報告書－第45期(2022/03/01－2023/02/28)	2025-05-19 09:20
# E12437	S100VQBJ	パインブリッジ・インベストメンツ株式会社	有価証券報告書（内国投資信託受益証券）－第42期(2024/08/21－2025/02/20)	2025-05-19 09:22
# E03268	S100VRV0	イオン北海道株式会社	訂正有価証券報告書－第46期(2023/03/01－2024/02/29)	2025-05-19 09:25
# E12437	S100VQBT	パインブリッジ・インベストメンツ株式会社	有価証券報告書（内国投資信託受益証券）－第41期(2024/08/21－2025/02/20)	2025-05-19 09:32
# E03137	S100VRWR	株式会社しまむら	有価証券報告書－第72期(2024/02/21－2025/02/20)	2025-05-19 09:32
# E12457	S100VRN9	ゴールドマン・サックス・アセット・マネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第20期(2024/08/20－2025/02/19)	2025-05-19 09:41
# E12492	S100VL4K	ＨＳＢＣアセットマネジメント株式会社	有価証券報告書（内国投資信託受益証券）－第14期(2024/08/20－2025/02/19)	2025-05-19 09:45
# E04874	S100VRS0	イオンディライト株式会社	有価証券報告書－第52期(2024/03/01－2025/02/28)	2025-05-19 16:02
